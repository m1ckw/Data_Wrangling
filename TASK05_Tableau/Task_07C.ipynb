# %% [markdown]
# <hr style="height:1px; width:100%">
#
# <h1 style="color:#336699">TASK 07PC: Recreating Task 4P as a Tableau Dashboard</h1>
#
# <p style="color:#204060; font-size:16px";>
#     Created by: &emsp;&emsp;&emsp; Mick Wiedermann<br>
#     Student Number: &ensp;2220-58299<br>
#     Email Address: &emsp;&ensp; mwiedermann@deakin.edu.au<br><br>
#     <i>Computer Science Undergraduate - Data Science Major</i>
# </p>
#
# <hr style="height:1px; width:100%">
#
#
# <p style="color:#336699; font-size:16px";><i>Description</i></p>

# %% [markdown]
# For this task I chose to use Tableau to create a dashboard. After importing the data I completed the following tasks:
#
# 1. Converted all imperial measurements to metric.
#
#
# 2. Adjusted the *time_hour* column deducted an hour so the data was inline with other parameters.
#
#
# 3. Computed the daily mean temperature values for all three airports.
#
#
# 4. Plotted the daily mean temperatures adding a filter to select any or all airports.
#
#
# 5. Displayed the five hottest adding a filter to select any or all airports.
#
# Below are a few images of my dashboard demonstrating how the filter works. You can view my dashboard [here](https://public.tableau.com/app/profile/mick.wiedermann/viz/Task_07C_4P_Dashboard/Dashboard1#1).

# %% [markdown]
# ## Dashboard Filter Set to: JFK

# %% [markdown]
# ![JFK.png](attachment:JFK.png)

# %% [markdown]
# ## Dashboard Filter Set to: EWR

# %% [markdown]
# ![EWR.png](attachment:EWR.png)

# %% [markdown]
# ## Dashboard Filter Set to: LGA

# %% [markdown]
# ![LGA.png](attachment:LGA.png)

# %% [markdown]
# ## Dashboard Filter Set to: ALL

# %% [markdown]
# ![ALL.png](attachment:ALL.png)

# %% [markdown]
# Dashboard URL: https://public.tableau.com/app/profile/mick.wiedermann/viz/Task_07C_4P_Dashboard/Dashboard1#1
